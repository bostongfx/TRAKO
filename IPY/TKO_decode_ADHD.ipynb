# %%
# %pylab inline
import os, sys
sys.path.append('../')
import trako as TKO

# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tko_file = '/tmp/test.tko'

# %%
polydata = TKO.Decoder.toVtp(tko_file)
# Out:
# Restored NormalizedSignalEstimationError
# Restored EstimatedUncertainty
# Restored RTOP1
# Restored RTOP2
# Restored RTAP1
# Restored RTAP2
# Restored RTPP1
# Restored RTPP2
# Restored SignalMean
# Restored EmbeddingCoordinate
# Restored ClusterNumber
# Restored EmbeddingColor
# Restored TotalFiberSimilarity
# Restored MeasuredFiberSimilarity

# %%
print(polydata)
# Out:
# vtkPolyData (0x55a3e9d058e0)
#   Debug: Off
#   Modified Time: 246
#   Reference Count: 1
#   Registered Events: (none)
#   Information: 0x55a3e9c7d630
#   Data Released: False
#   Global Release Data: Off
#   UpdateTime: 0
#   Field Data:
#     Debug: Off
#     Modified Time: 144
#     Reference Count: 1
#     Registered Events: (none)
#     Number Of Arrays: 0
#     Number Of Components: 0
#     Number Of Tuples: 0
#   Number Of Points: 22585
#   Number Of Cells: 190
#   Cell Data:
#     Debug: Off
#     Modified Time: 246
#     Reference Count: 1
#     Registered Events:
#       Registered Observers:
#         vtkObserver (0x55a3e9d02390)
#           Event: 33
#           EventName: ModifiedEvent
#           Command: 0x55a3e9c699a0
#           Priority: 0
#           Tag: 1
#     Number Of Arrays: 5
#     Array 0 name = EmbeddingCoordinate
#     Array 1 name = ClusterNumber
#     Array 2 name = EmbeddingColor
#     Array 3 name = TotalFiberSimilarity
#     Array 4 name = MeasuredFiberSimilarity
#     Number Of Components: 16
#     Number Of Tuples: 190
#     Copy Tuple Flags: ( 1 1 1 1 1 0 1 1 )
#     Interpolate Flags: ( 1 1 1 1 1 0 0 1 )
#     Pass Through Flags: ( 1 1 1 1 1 1 1 1 )
#     Scalars: (none)
#     Vectors: (none)
#     Normals: (none)
#     TCoords: (none)
#     Tensors: (none)
#     GlobalIds: (none)
#     PedigreeIds: (none)
#     EdgeFlag: (none)
#   Point Data:
#     Debug: Off
#     Modified Time: 210
#     Reference Count: 1
#     Registered Events:
#       Registered Observers:
#         vtkObserver (0x55a3e9d644f0)
#           Event: 33
#           EventName: ModifiedEvent
#           Command: 0x55a3e9c699a0
#           Priority: 0
#           Tag: 1
#     Number Of Arrays: 9
#     Array 0 name = NormalizedSignalEstimationError
#     Array 1 name = EstimatedUncertainty
#     Array 2 name = RTOP1
#     Array 3 name = RTOP2
#     Array 4 name = RTAP1
#     Array 5 name = RTAP2
#     Array 6 name = RTPP1
#     Array 7 name = RTPP2
#     Array 8 name = SignalMean
#     Number Of Components: 9
#     Number Of Tuples: 22585
#     Copy Tuple Flags: ( 1 1 1 1 1 0 1 1 )
#     Interpolate Flags: ( 1 1 1 1 1 0 0 1 )
#     Pass Through Flags: ( 1 1 1 1 1 1 1 1 )
#     Scalars: (none)
#     Vectors: (none)
#     Normals: (none)
#     TCoords: (none)
#     Tensors: (none)
#     GlobalIds: (none)
#     PedigreeIds: (none)
#     EdgeFlag: (none)
#   Bounds:
#     Xmin,Xmax: (-50.2295, -14.6692)
#     Ymin,Ymax: (-28.4074, 34.4118)
#     Zmin,Zmax: (23.6043, 61.4308)
#   Compute Time: 247
#   Number Of Points: 22585
#   Point Coordinates: 0x55a3e9d03460
#   Locator: 0
#   Number Of Vertices: 0
#   Number Of Lines: 190
#   Number Of Polygons: 0
#   Number Of Triangle Strips: 0
#   Number Of Pieces: 1
#   Piece: -1
#   Ghost Level: 0

# %%
import vtk

# %%
import vtk
from vtk.util import numpy_support
DATADIR = '/home/d/DATA/Dropbox/ADHD_STFC_diff_for_Daniel/'
SUBJECTS = ['101','201']
GROUP = ['tracts_left_hemisphere']
files = os.listdir(os.path.join(DATADIR,SUBJECTS[0],GROUP[0]))

vtp_file = os.path.join(DATADIR,SUBJECTS[0],GROUP[0],files[0])
r = vtk.vtkXMLPolyDataReader()
r.SetFileName(vtp_file)
r.Update()
polydata = r.GetOutput()

# %%
print(polydata)
# Out:
# vtkPolyData (0x55a3e9da9c40)
#   Debug: Off
#   Modified Time: 845
#   Reference Count: 2
#   Registered Events: (none)
#   Information: 0x55a3e88d03c0
#   Data Released: False
#   Global Release Data: Off
#   UpdateTime: 868
#   Field Data:
#     Debug: Off
#     Modified Time: 595
#     Reference Count: 1
#     Registered Events: (none)
#     Number Of Arrays: 0
#     Number Of Components: 0
#     Number Of Tuples: 0
#   Number Of Points: 22585
#   Number Of Cells: 190
#   Cell Data:
#     Debug: Off
#     Modified Time: 840
#     Reference Count: 1
#     Registered Events:
#       Registered Observers:
#         vtkObserver (0x55a3e9da9ec0)
#           Event: 33
#           EventName: ModifiedEvent
#           Command: 0x55a3e88d0490
#           Priority: 0
#           Tag: 1
#     Number Of Arrays: 5
#     Array 0 name = EmbeddingCoordinate
#     Array 1 name = ClusterNumber
#     Array 2 name = EmbeddingColor
#     Array 3 name = TotalFiberSimilarity
#     Array 4 name = MeasuredFiberSimilarity
#     Number Of Components: 16
#     Number Of Tuples: 190
#     Copy Tuple Flags: ( 1 1 1 1 1 0 1 1 )
#     Interpolate Flags: ( 1 1 1 1 1 0 0 1 )
#     Pass Through Flags: ( 1 1 1 1 1 1 1 1 )
#     Scalars: (none)
#     Vectors: (none)
#     Normals: (none)
#     TCoords: (none)
#     Tensors: (none)
#     GlobalIds: (none)
#     PedigreeIds: (none)
#     EdgeFlag: (none)
#   Point Data:
#     Debug: Off
#     Modified Time: 755
#     Reference Count: 1
#     Registered Events:
#       Registered Observers:
#         vtkObserver (0x55a3e9d05280)
#           Event: 33
#           EventName: ModifiedEvent
#           Command: 0x55a3e88d0490
#           Priority: 0
#           Tag: 1
#     Number Of Arrays: 9
#     Array 0 name = NormalizedSignalEstimationError
#     Array 1 name = EstimatedUncertainty
#     Array 2 name = RTOP1
#     Array 3 name = RTOP2
#     Array 4 name = RTAP1
#     Array 5 name = RTAP2
#     Array 6 name = RTPP1
#     Array 7 name = RTPP2
#     Array 8 name = SignalMean
#     Number Of Components: 9
#     Number Of Tuples: 22585
#     Copy Tuple Flags: ( 1 1 1 1 1 0 1 1 )
#     Interpolate Flags: ( 1 1 1 1 1 0 0 1 )
#     Pass Through Flags: ( 1 1 1 1 1 1 1 1 )
#     Scalars: (none)
#     Vectors: (none)
#     Normals: (none)
#     TCoords: (none)
#     Tensors: (none)
#     GlobalIds: (none)
#     PedigreeIds: (none)
#     EdgeFlag: (none)
#   Bounds:
#     Xmin,Xmax: (-50.2295, -14.6694)
#     Ymin,Ymax: (-28.4074, 34.4118)
#     Zmin,Zmax: (23.6043, 61.4305)
#   Compute Time: 903
#   Number Of Points: 22585
#   Point Coordinates: 0x55a3e9da9bc0
#   Locator: 0
#   Number Of Vertices: 0
#   Number Of Lines: 190
#   Number Of Polygons: 0
#   Number Of Triangle Strips: 0
#   Number Of Pieces: 1
#   Piece: 0
#   Ghost Level: 0
